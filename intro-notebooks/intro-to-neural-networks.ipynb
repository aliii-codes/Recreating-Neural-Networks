# %% [markdown]
# # What is a neural Network ?
#
# **Artifical** neural netwroks are inspired by organic brain , translated to the computer. It's not a perfect comparison, but there are neurons , activation, and lots of interconnectivity , even if the underlying processes are quite diefferent. <br>
# <br>
#
# A single neuron by itself is relatively useless, but , when combiner with hundereds of thousands of (or many more) of other neurons , the interconnectivity produces relationships and results that frequently outperform any other ML methods. <br>
# <br>
#
# **Check:** <br> https://nnfs.io/ntr <br> <br> <br>
# the above animation shows the examples of the model strucures and the number of parameters the model has to learn to adjust just in order to prodyce desired outpurs. The details of what is seen here are the subjects of future chapters.
#
# <br>
# <br>
#
# **Neural Networks** are considered to be "black boxes" in what we often have no ideas why they reach the cinclutions they do. We do understand how they do this , though.
#
# <br>
# <br>
#
# A neuron consists of an input , weight , and a bias.
#
# <br>
# Output of one neuron becomes **Input** for another.
# <br>
#
# The Concept of biases and weights can be thought of as **knobs** that we can tune to fit our model to data.
